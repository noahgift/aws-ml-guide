# %% [markdown]
# <a href="https://colab.research.google.com/github/noahgift/aws-ml-guide/blob/master/Lesson7_AWSML_Case_Studies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 7: Case Studies
#
# [Watch Lesson 7:  Case Studies Video](https://learning.oreilly.com/videos/aws-certified-machine/9780135556597/9780135556597-ACML_01_07_00)

# %% [markdown]
# ## Pragmatic AI Labs

# %% [markdown]
# ![alt text](https://paiml.com/images/logo_with_slogan_white_background.png)
#
# This notebook was produced by [Pragmatic AI Labs](https://paiml.com/).  You can continue learning about these topics by:
#
# *   Buying a copy of [Pragmatic AI: An Introduction to Cloud-Based Machine Learning](http://www.informit.com/store/pragmatic-ai-an-introduction-to-cloud-based-machine-9780134863863) from Informit.
# *   Buying a copy of  [Pragmatic AI: An Introduction to Cloud-Based Machine Learning](https://www.amazon.com/Pragmatic-AI-Introduction-Cloud-Based-Learning/dp/0134863860) from Amazon
# *   Reading an online copy of [Pragmatic AI:Pragmatic AI: An Introduction to Cloud-Based Machine Learning](https://www.safaribooksonline.com/library/view/pragmatic-ai-an/9780134863924/)
# *  Watching video [Essential Machine Learning and AI with Python and Jupyter Notebook-Video-SafariOnline](https://www.safaribooksonline.com/videos/essential-machine-learning/9780135261118) on Safari Books Online.
# * Watching video [AWS Certified Machine Learning-Speciality](https://learning.oreilly.com/videos/aws-certified-machine/9780135556597)
# * Purchasing video [Essential Machine Learning and AI with Python and Jupyter Notebook- Purchase Video](http://www.informit.com/store/essential-machine-learning-and-ai-with-python-and-jupyter-9780135261095)
# *   Viewing more content at [noahgift.com](https://noahgift.com/)

# %% [markdown]
# ## Load AWS API Keys

# %% [markdown]
# Put keys in local or remote GDrive:
#
# `cp ~/.aws/credentials /Users/myname/Google\ Drive/awsml/`

# %% [markdown]
# ### Mount GDrive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os;os.listdir("/content/gdrive/My Drive/awsml")
# Out:
# ['kaggle.json', 'credentials', 'config']

# %% [markdown]
# ### Install Boto

# %%
# !pip -q install boto3

# %% [markdown]
# ### Create API Config

# %%
# !mkdir -p ~/.aws &&\
  cp /content/gdrive/My\ Drive/awsml/credentials ~/.aws/credentials

# %% [markdown]
# ### Test Comprehend API Call

# %%
import boto3
comprehend = boto3.client(service_name='comprehend', region_name="us-east-1")
text = "There is smoke in San Francisco"
comprehend.detect_sentiment(Text=text, LanguageCode='en')
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#    'content-length': '160',
#    'content-type': 'application/x-amz-json-1.1',
#    'date': 'Fri, 14 Dec 2018 16:11:55 GMT',
#    'x-amzn-requestid': 'fa00db36-ffba-11e8-882b-8bc33ca9084d'},
#   'HTTPStatusCode': 200,
#   'RequestId': 'fa00db36-ffba-11e8-882b-8bc33ca9084d',
#   'RetryAttempts': 0},
#  'Sentiment': 'NEUTRAL',
#  'SentimentScore': {'Mixed': 0.008628507144749165,
#   'Negative': 0.1037612184882164,
#   'Neutral': 0.8582549691200256,
#   'Positive': 0.0293553676456213}}

# %% [markdown]
# ## 7.1 Sagemaker Features

# %% [markdown]
# ### Search

# %% [markdown]
# #### [Demo] Search

# %% [markdown]
# [Manage Machine Learning Experiments with Search](https://docs.aws.amazon.com/sagemaker/latest/dg/search.html)
#
#
#
# *   Finding training jobs
# *   Rank training jobs
# *   Tracing lineage of a model

# %% [markdown]
# ### Ground Truth

# %% [markdown]
# ![ground_truth](https://user-images.githubusercontent.com/58792/49688683-9bdba100-faca-11e8-8d93-a55ce6c35a92.png)
#
#
#
# *   Setup and Manage labeling jobs
# *   Uses active learning and human labeling
# *   First 500 objects labeled per month are free

# %% [markdown]
# #### [Demo] Labeling Job

# %% [markdown]
# ### Notebook

# %% [markdown]
# ![notebooks](https://user-images.githubusercontent.com/58792/49688694-d04f5d00-faca-11e8-9fad-eb63b2534b07.png)

# %% [markdown]
# #### [Demo] Sagemaker Notebooks
#
# *   Create and run Jupyter Notebooks
#   -  Using Jupyter
#   -  Using JupyterLab
#   -  Using the terminal
#
# *   Lifecycle configurations
#
# *   Git Repositories
#   - public repositories can be cloned on Notebook launch

# %% [markdown]
# ### Training

# %% [markdown]
# ![training](https://user-images.githubusercontent.com/58792/49688717-05f44600-facb-11e8-8d7f-cf33d272573a.png)

# %% [markdown]
# #### [Demo] Sagemaker Training
#
# *   Algorithms
#   -  Create algorithm
#   -  Subscribe [AWS Marketplace](https://aws.amazon.com/marketplace/search/results?page=1&filters=fulfillment_options%2Cresource_type&fulfillment_options=SAGEMAKER&resource_type=ALGORITHM)
#
#
# *   Training Jobs
#
# *   HyperParameter Tuning Jobs

# %% [markdown]
# ### Inference

# %% [markdown]
# ![inference](https://user-images.githubusercontent.com/58792/49688735-2fad6d00-facb-11e8-94cb-cba9322e309b.png)

# %% [markdown]
# #### [Demo] Sagemaker Inference
#
# *  Compilation jobs
#
# *  Model packages
#
# *  Models
#
# *  Endpoint configurations
#
# *  Endpoints
#
# *  Batch transform jobs

# %% [markdown]
# ### Built in Sagemaker Algorithms

# %% [markdown]
# Table of [algorithms provided by Amazon Sagemaker](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html)
#
# ![aws_algorithms](https://user-images.githubusercontent.com/58792/49692597-58595500-fb13-11e8-9db3-e1fe371ac36a.png)

# %% [markdown]
# ## 7.2 DeepLense Features

# %% [markdown]
# ![tech_specs](https://user-images.githubusercontent.com/58792/50003518-c0b39680-ff58-11e8-86dc-5a57e1482ef3.png)

# %% [markdown]
# ![mqt](https://user-images.githubusercontent.com/58792/45307777-bfe01400-b4d4-11e8-88a3-149317f9dffc.png)

# %% [markdown]
# ![detection](https://user-images.githubusercontent.com/58792/45308029-688e7380-b4d5-11e8-8ffb-9422184c274c.png)

# %% [markdown]
# #### [Demo] DeepLense

# %% [markdown]
# ## 7.3 Kinesis Features

# %% [markdown]
# [Kinesis FAQ](https://aws.amazon.com/kinesis/data-streams/faqs/)
#
# * Processes Data in Real-Time
# * Can process hundreds of TBs an hour
# * Example inputs are:
#  - logs
#  - financial transactions
#  * Streaming Data

# %%
# !pip install -q sensible

# %%
import boto3

# %%
import asyncio
import time
import datetime
import uuid
import boto3
import json
from sensible.loginit import logger

LOG = logger(__name__)

def firehose_client(region_name="us-east-1"):
    """Kinesis Firehose client"""

    firehose_conn = boto3.client("firehose", region_name=region_name)
    extra_msg = {"region_name": region_name, "aws_service": "firehose"}
    LOG.info("firehose connection initiated", extra=extra_msg)
    return firehose_conn

async def put_record(data,
            client,
            delivery_stream_name="aws-ml-cert"):
    """
    See this:
        http://boto3.readthedocs.io/en/latest/reference/services/
        firehose.html#Firehose.Client.put_record
    """
    extra_msg = {"aws_service": "firehose"}
    LOG.info(f"Pushing record to firehose: {data}", extra=extra_msg)
    response = client.put_record(
        DeliveryStreamName=delivery_stream_name,
        Record={
            'Data': data
        }
    )
    return response


def gen_uuid_events():
    """Creates a time stamped UUID based event"""

    current_time = 'test-{date:%Y-%m-%d %H:%M:%S}'.format(date=datetime.datetime.now())
    event_id = str(uuid.uuid4())
    event = {event_id:current_time}
    return json.dumps(event)

def send_async_firehose_events(count=100):
    """Async sends events to firehose"""

    start = time.time() 
    client = firehose_client()
    extra_msg = {"aws_service": "firehose"}
    loop = asyncio.get_event_loop()
    tasks = []
    LOG.info(f"sending aysnc events TOTAL {count}",extra=extra_msg)
    num = 0
    for _ in range(count):
        tasks.append(asyncio.ensure_future(put_record(gen_uuid_events(), client)))
        LOG.info(f"sending aysnc events: COUNT {num}/{count}")
        num +=1
    loop.run_until_complete(asyncio.wait(tasks))
    loop.close()
    end = time.time()  
    LOG.info("Total time: {}".format(end - start))

# %%
send_async_firehose_events(10)
# Out:
# 2018-12-14 18:49:58,211 - __main__ - INFO - firehose connection initiated
# 2018-12-14 18:49:58,213 - __main__ - INFO - sending aysnc events TOTAL 10
# 2018-12-14 18:49:58,214 - __main__ - INFO - sending aysnc events: COUNT 0/10
# 2018-12-14 18:49:58,216 - __main__ - INFO - sending aysnc events: COUNT 1/10
# 2018-12-14 18:49:58,220 - __main__ - INFO - sending aysnc events: COUNT 2/10
# 2018-12-14 18:49:58,221 - __main__ - INFO - sending aysnc events: COUNT 3/10
# 2018-12-14 18:49:58,225 - __main__ - INFO - sending aysnc events: COUNT 4/10
# 2018-12-14 18:49:58,228 - __main__ - INFO - sending aysnc events: COUNT 5/10
# 2018-12-14 18:49:58,231 - __main__ - INFO - sending aysnc events: COUNT 6/10
# 2018-12-14 18:49:58,233 - __main__ - INFO - sending aysnc events: COUNT 7/10
# 2018-12-14 18:49:58,236 - __main__ - INFO - sending aysnc events: COUNT 8/10
# 2018-12-14 18:49:58,237 - __main__ - INFO - sending aysnc events: COUNT 9/10
# 2018-12-14 18:49:58,242 - __main__ - INFO - Pushing record to firehose: {"23bacac0-6eff-410f-b655-a7faa122b68f": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,364 - __main__ - INFO - Pushing record to firehose: {"03b15c89-e0a2-46b8-b8d3-cdd71e2ab140": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,404 - __main__ - INFO - Pushing record to firehose: {"5ff296d3-f43a-4e69-b61b-624603a354b4": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,448 - __main__ - INFO - Pushing record to firehose: {"7ca78179-7ff7-49d1-bd6c-08ca5569737c": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,486 - __main__ - INFO - Pushing record to firehose: {"554e587b-2d59-4e4f-95a3-75e4fb129c60": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,511 - __main__ - INFO - Pushing record to firehose: {"30532d9e-6f3a-4366-b6ab-3bf9291c4e0b": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,548 - __main__ - INFO - Pushing record to firehose: {"99cdff7d-32d1-424b-886e-9e93bb5e5a03": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,575 - __main__ - INFO - Pushing record to firehose: {"8ea0c709-a8a5-4bde-9454-c6dd5691d58a": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,610 - __main__ - INFO - Pushing record to firehose: {"99ce9671-7971-415c-9c64-ac2c82f9f478": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,643 - __main__ - INFO - Pushing record to firehose: {"dc515833-8474-4377-9514-0f6d6fcfa403": "test-2018-12-14 18:49:58"}
# 2018-12-14 18:49:58,677 - __main__ - INFO - Total time: 0.5094583034515381

# %% [markdown]
# ## 7.4 AWS Flavored Python

# %% [markdown]
# ### Boto3

# %% [markdown]
# * Main Interface for working with AWS
#
# *   Any Service in AWS can be communicated with Boto
# *  If Amazon is a country this is the language

# %% [markdown]
# #### Communicate with S3

# %%
import boto3
resource = boto3.resource("s3")
resource.meta.client.download_file('testntest', 'nba_2017_endorsement_full_stats.csv',
'/tmp/nba_2017_endorsement_full_stats.csv')
# Out:
# {"message": "Loading JSON file: /usr/local/lib/python3.6/dist-packages/boto3/data/s3/2006-03-01/resources-1.json"}
# {"message": "Loading JSON file: /usr/local/lib/python3.6/dist-packages/boto3/data/s3/2006-03-01/resources-1.json"}
# {"message": "Event choose-service-name: calling handler <function handle_service_name_alias at 0x7f8fb5845950>"}
# {"message": "Event choose-service-name: calling handler <function handle_service_name_alias at 0x7f8fb5845950>"}
# {"message": "Loading JSON file: /usr/local/lib/python3.6/dist-packages/botocore/data/s3/2006-03-01/service-2.json"}
# {"message": "Loading JSON file: /usr/local/lib/python3.6/dist-packages/botocore/data/s3/2006-03-01/service-2.json"}
# {"message": "Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x7f8fb588f598>"}
# {"message": "Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x7f8fb588f598>"}
# {"message": "Event creating-client-class.s3: calling handler <function lazy_call.<locals>._handler at 0x7f8fb54f9730>"}
# {"message": "Event creating-client-class.s3: calling handler <function lazy_call.<locals>._handler at 0x7f8fb54f9730>"}
# {"message": "Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x7f8fb588f378>"}
# {"message": "Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x7f8fb588f378>"}
# {"message": "The s3 config key is not a dictionary type, ignoring its value of: None"}
# {"message": "The s3 config key is not a dictionary type, ignoring its value of: None"}
# {"message": "Setting s3 timeout as (60, 60)"}
# {"message": "Setting s3 timeout as (60, 60)"}
# {"message": "Registering retry handlers for service: s3"}
# {"message": "Registering retry handlers for service: s3"}
# {"message": "Defaulting to S3 virtual host style addressing with path style addressing fallback."}
# {"message": "Defaulting to S3 virtual host style addressing with path style addressing fallback."}
# {"message": "Loading s3:s3"}
# {"message": "Loading s3:s3"}
# {"message": "Acquiring 0"}
# {"message": "Acquiring 0"}
# {"message": "DownloadSubmissionTask(transfer_id=0, {'transfer_future': <s3transfer.futures.TransferFuture object at 0x7f8fb4a63dd8>}) about to wait for the following futures []"}
# {"message": "DownloadSubmissionTask(transfer_id=0, {'transfer_future': <s3transfer.futures.TransferFuture object at 0x7f8fb4a63dd8>}) about to wait for the following futures []"}
# {"message": "DownloadSubmissionTask(transfer_id=0, {'transfer_future': <s3transfer.futures.TransferFuture object at 0x7f8fb4a63dd8>}) done waiting for dependent futures"}
# {"message": "DownloadSubmissionTask(transfer_id=0, {'transfer_future': <s3transfer.futures.TransferFuture object at 0x7f8fb4a63dd8>}) done waiting for dependent futures"}
# {"message": "Executing task DownloadSubmissionTask(transfer_id=0, {'transfer_future': <s3transfer.futures.TransferFuture object at 0x7f8fb4a63dd8>}) with kwargs {'client': <botocore.client.S3 object at 0x7f8fb4b36978>, 'config': <boto3.s3.transfer.TransferConfig object at 0x7f8fb4a63400>, 'osutil': <s3transfer.utils.OSUtils object at 0x7f8fb4a63470>, 'request_executor': <s3transfer.futures.BoundedExecutor object at 0x7f8fb4a63668>, 'transfer_future': <s3transfer.futures.TransferFuture object at 0x7f8fb4a63dd8>, 'io_executor': <s3transfer.futures.BoundedExecutor object at 0x7f8fb4a63ac8>}"}
# {"message": "Executing task DownloadSubmissionTask(transfer_id=0, {'transfer_future': <s3transfer.futures.TransferFuture object at 0x7f8fb4a63dd8>}) with kwargs {'client': <botocore.client.S3 object at 0x7f8fb4b36978>, 'config': <boto3.s3.transfer.TransferConfig object at 0x7f8fb4a63400>, 'osutil': <s3transfer.utils.OSUtils object at 0x7f8fb4a63470>, 'request_executor': <s3transfer.futures.BoundedExecutor object at 0x7f8fb4a63668>, 'transfer_future': <s3transfer.futures.TransferFuture object at 0x7f8fb4a63dd8>, 'io_executor': <s3transfer.futures.BoundedExecutor object at 0x7f8fb4a63ac8>}"}
# {"message": "Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7f8fb5860400>"}
# {"message": "Event before-parameter-build.s3.HeadObject: calling handler <function sse_md5 at 0x7f8fb5860400>"}
# {"message": "Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7f8fb5860378>"}
# {"message": "Event before-parameter-build.s3.HeadObject: calling handler <function validate_bucket_name at 0x7f8fb5860378>"}
# {"message": "Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-parameter-build.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-parameter-build.s3.HeadObject: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7f8fb5860840>"}
# {"message": "Event before-call.s3.HeadObject: calling handler <function add_expect_header at 0x7f8fb5860840>"}
# {"message": "Event before-call.s3.HeadObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-call.s3.HeadObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Making request for OperationModel(name=HeadObject) with params: {'url_path': '/testntest/nba_2017_endorsement_full_stats.csv', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource'}, 'body': b'', 'url': 'https://s3.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb4b36c18>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'testntest'}}}"}
# {"message": "Making request for OperationModel(name=HeadObject) with params: {'url_path': '/testntest/nba_2017_endorsement_full_stats.csv', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource'}, 'body': b'', 'url': 'https://s3.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb4b36c18>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'testntest'}}}"}
# {"message": "Event request-created.s3.HeadObject: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.HeadObject: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event before-sign.s3.HeadObject: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Event before-sign.s3.HeadObject: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Checking for DNS compatible bucket for: https://s3.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "Checking for DNS compatible bucket for: https://s3.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "URI updated to: https://testntest.s3.amazonaws.com/nba_2017_endorsement_full_stats.csv"}
# {"message": "URI updated to: https://testntest.s3.amazonaws.com/nba_2017_endorsement_full_stats.csv"}
# {"message": "Calculating signature using v4 auth."}
# {"message": "Calculating signature using v4 auth."}
# {"message": "CanonicalRequest:\nHEAD\n/nba_2017_endorsement_full_stats.csv\n\nhost:testntest.s3.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190639Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "CanonicalRequest:\nHEAD\n/nba_2017_endorsement_full_stats.csv\n\nhost:testntest.s3.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190639Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190639Z\n20181214/us-east-1/s3/aws4_request\ndc464718e66f61dbbd6306f072011e817a11700464a81c78e77bac008daaa11b"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190639Z\n20181214/us-east-1/s3/aws4_request\ndc464718e66f61dbbd6306f072011e817a11700464a81c78e77bac008daaa11b"}
# {"message": "Signature:\ndccf5cd1ba1f8ffd257e709de85d54d05de887bf6c7a0539fb74f037e3c727de"}
# {"message": "Signature:\ndccf5cd1ba1f8ffd257e709de85d54d05de887bf6c7a0539fb74f037e3c727de"}
# {"message": "Event request-created.s3.HeadObject: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Event request-created.s3.HeadObject: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://testntest.s3.amazonaws.com/nba_2017_endorsement_full_stats.csv, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190639Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=dccf5cd1ba1f8ffd257e709de85d54d05de887bf6c7a0539fb74f037e3c727de'}>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://testntest.s3.amazonaws.com/nba_2017_endorsement_full_stats.csv, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190639Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=dccf5cd1ba1f8ffd257e709de85d54d05de887bf6c7a0539fb74f037e3c727de'}>"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Starting new HTTPS connection (1): testntest.s3.amazonaws.com"}
# {"message": "Starting new HTTPS connection (1): testntest.s3.amazonaws.com"}
# {"message": "https://testntest.s3.amazonaws.com:443 \"HEAD /nba_2017_endorsement_full_stats.csv HTTP/1.1\" 400 0"}
# {"message": "https://testntest.s3.amazonaws.com:443 \"HEAD /nba_2017_endorsement_full_stats.csv HTTP/1.1\" 400 0"}
# {"message": "Response headers: {'x-amz-request-id': '22146DB0C1CFB102', 'x-amz-id-2': 'L5unIiNB7+FTulP8F6l1f4Blmuo6WKNSZ5oKnNlJI4QMN/lL6amNBiEKIyFg7MgUmogD/X4FA2o=', 'Content-Type': 'application/xml', 'Transfer-Encoding': 'chunked', 'Date': 'Fri, 14 Dec 2018 19:06:39 GMT', 'Connection': 'close', 'Server': 'AmazonS3'}"}
# {"message": "Response headers: {'x-amz-request-id': '22146DB0C1CFB102', 'x-amz-id-2': 'L5unIiNB7+FTulP8F6l1f4Blmuo6WKNSZ5oKnNlJI4QMN/lL6amNBiEKIyFg7MgUmogD/X4FA2o=', 'Content-Type': 'application/xml', 'Transfer-Encoding': 'chunked', 'Date': 'Fri, 14 Dec 2018 19:06:39 GMT', 'Connection': 'close', 'Server': 'AmazonS3'}"}
# {"message": "Response body:\nb''"}
# {"message": "Response body:\nb''"}
# {"message": "Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "No retry needed."}
# {"message": "No retry needed."}
# {"message": "Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-parameter-build.s3.HeadBucket: calling handler <function validate_bucket_name at 0x7f8fb5860378>"}
# {"message": "Event before-parameter-build.s3.HeadBucket: calling handler <function validate_bucket_name at 0x7f8fb5860378>"}
# {"message": "Event before-parameter-build.s3.HeadBucket: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-parameter-build.s3.HeadBucket: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-parameter-build.s3.HeadBucket: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-parameter-build.s3.HeadBucket: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-call.s3.HeadBucket: calling handler <function add_expect_header at 0x7f8fb5860840>"}
# {"message": "Event before-call.s3.HeadBucket: calling handler <function add_expect_header at 0x7f8fb5860840>"}
# {"message": "Event before-call.s3.HeadBucket: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-call.s3.HeadBucket: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Making request for OperationModel(name=HeadBucket) with params: {'url_path': '/testntest', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource'}, 'body': b'', 'url': 'https://s3.amazonaws.com/testntest', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb4b36c18>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'testntest'}}}"}
# {"message": "Making request for OperationModel(name=HeadBucket) with params: {'url_path': '/testntest', 'query_string': {}, 'method': 'HEAD', 'headers': {'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource'}, 'body': b'', 'url': 'https://s3.amazonaws.com/testntest', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb4b36c18>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'bucket': 'testntest'}}}"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event choose-signer.s3.HeadBucket: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.HeadBucket: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.HeadBucket: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event choose-signer.s3.HeadBucket: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event before-sign.s3.HeadBucket: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Event before-sign.s3.HeadBucket: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Checking for DNS compatible bucket for: https://s3.amazonaws.com/testntest"}
# {"message": "Checking for DNS compatible bucket for: https://s3.amazonaws.com/testntest"}
# {"message": "URI updated to: https://testntest.s3.amazonaws.com/"}
# {"message": "URI updated to: https://testntest.s3.amazonaws.com/"}
# {"message": "Calculating signature using v4 auth."}
# {"message": "Calculating signature using v4 auth."}
# {"message": "CanonicalRequest:\nHEAD\n/\n\nhost:testntest.s3.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190639Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "CanonicalRequest:\nHEAD\n/\n\nhost:testntest.s3.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190639Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190639Z\n20181214/us-east-1/s3/aws4_request\n799fcd8c0621e283d6b947f1e3d95eef142741deedd165dd48ee8811d5f9d852"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190639Z\n20181214/us-east-1/s3/aws4_request\n799fcd8c0621e283d6b947f1e3d95eef142741deedd165dd48ee8811d5f9d852"}
# {"message": "Signature:\n662dcd262b4b95999730c002394be231cf02ad3b1d8cc90da9399bfd585bc1e7"}
# {"message": "Signature:\n662dcd262b4b95999730c002394be231cf02ad3b1d8cc90da9399bfd585bc1e7"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://testntest.s3.amazonaws.com/, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190639Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=662dcd262b4b95999730c002394be231cf02ad3b1d8cc90da9399bfd585bc1e7'}>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://testntest.s3.amazonaws.com/, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190639Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=662dcd262b4b95999730c002394be231cf02ad3b1d8cc90da9399bfd585bc1e7'}>"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Starting new HTTPS connection (2): testntest.s3.amazonaws.com"}
# {"message": "Starting new HTTPS connection (2): testntest.s3.amazonaws.com"}
# {"message": "https://testntest.s3.amazonaws.com:443 \"HEAD / HTTP/1.1\" 400 0"}
# {"message": "https://testntest.s3.amazonaws.com:443 \"HEAD / HTTP/1.1\" 400 0"}
# {"message": "Response headers: {'x-amz-bucket-region': 'us-east-2', 'x-amz-request-id': '269DCC355D0E8FC5', 'x-amz-id-2': 'zDCOaU9LZsqhOzJNjRUBAl/pNuU9j05NC1GAxcfrjdhft16LSuDDk2Ay3Hu8j6kk2kmUx55SZSo=', 'Content-Type': 'application/xml', 'Transfer-Encoding': 'chunked', 'Date': 'Fri, 14 Dec 2018 19:06:39 GMT', 'Connection': 'close', 'Server': 'AmazonS3'}"}
# {"message": "Response headers: {'x-amz-bucket-region': 'us-east-2', 'x-amz-request-id': '269DCC355D0E8FC5', 'x-amz-id-2': 'zDCOaU9LZsqhOzJNjRUBAl/pNuU9j05NC1GAxcfrjdhft16LSuDDk2Ay3Hu8j6kk2kmUx55SZSo=', 'Content-Type': 'application/xml', 'Transfer-Encoding': 'chunked', 'Date': 'Fri, 14 Dec 2018 19:06:39 GMT', 'Connection': 'close', 'Server': 'AmazonS3'}"}
# {"message": "Response body:\nb''"}
# {"message": "Response body:\nb''"}
# {"message": "Event needs-retry.s3.HeadBucket: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "Event needs-retry.s3.HeadBucket: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "No retry needed."}
# {"message": "No retry needed."}
# {"message": "Event needs-retry.s3.HeadBucket: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event needs-retry.s3.HeadBucket: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "S3 client configured for region us-east-1 but the bucket testntest is in region us-east-2; Please configure the proper region to avoid multiple unnecessary redirects and signing attempts."}
# {"message": "S3 client configured for region us-east-1 but the bucket testntest is in region us-east-2; Please configure the proper region to avoid multiple unnecessary redirects and signing attempts."}
# {"message": "Updating URI from https://s3.amazonaws.com/testntest to https://s3.us-east-2.amazonaws.com/testntest"}
# {"message": "Updating URI from https://s3.amazonaws.com/testntest to https://s3.us-east-2.amazonaws.com/testntest"}
# {"message": "Response received to retry, sleeping for 0 seconds"}
# {"message": "Response received to retry, sleeping for 0 seconds"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event choose-signer.s3.HeadBucket: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.HeadBucket: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.HeadBucket: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event choose-signer.s3.HeadBucket: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event before-sign.s3.HeadBucket: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Event before-sign.s3.HeadBucket: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Checking for DNS compatible bucket for: https://s3.us-east-2.amazonaws.com/testntest"}
# {"message": "Checking for DNS compatible bucket for: https://s3.us-east-2.amazonaws.com/testntest"}
# {"message": "URI updated to: https://testntest.s3.us-east-2.amazonaws.com/"}
# {"message": "URI updated to: https://testntest.s3.us-east-2.amazonaws.com/"}
# {"message": "Calculating signature using v4 auth."}
# {"message": "Calculating signature using v4 auth."}
# {"message": "CanonicalRequest:\nHEAD\n/\n\nhost:testntest.s3.us-east-2.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190639Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "CanonicalRequest:\nHEAD\n/\n\nhost:testntest.s3.us-east-2.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190639Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190639Z\n20181214/us-east-2/s3/aws4_request\n871d114aad45e44f48590659e690e4bf80e931590de143cb6d43315e11738099"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190639Z\n20181214/us-east-2/s3/aws4_request\n871d114aad45e44f48590659e690e4bf80e931590de143cb6d43315e11738099"}
# {"message": "Signature:\ncf9f8ade13bca861c824070d31f9e931bce82e0339dffac638ead2c7a6d3a932"}
# {"message": "Signature:\ncf9f8ade13bca861c824070d31f9e931bce82e0339dffac638ead2c7a6d3a932"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Event request-created.s3.HeadBucket: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://testntest.s3.us-east-2.amazonaws.com/, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190639Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-2/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=cf9f8ade13bca861c824070d31f9e931bce82e0339dffac638ead2c7a6d3a932'}>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://testntest.s3.us-east-2.amazonaws.com/, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190639Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-2/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=cf9f8ade13bca861c824070d31f9e931bce82e0339dffac638ead2c7a6d3a932'}>"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Starting new HTTPS connection (1): testntest.s3.us-east-2.amazonaws.com"}
# {"message": "Starting new HTTPS connection (1): testntest.s3.us-east-2.amazonaws.com"}
# {"message": "https://testntest.s3.us-east-2.amazonaws.com:443 \"HEAD / HTTP/1.1\" 200 0"}
# {"message": "https://testntest.s3.us-east-2.amazonaws.com:443 \"HEAD / HTTP/1.1\" 200 0"}
# {"message": "Response headers: {'x-amz-id-2': 'TrkXI9rge0KJy+wVICwUfQAA5KlU5u8B98N8FegMqGYacUpn+4NnGpAkkpUgGdr9pbyruUjvcUQ=', 'x-amz-request-id': 'D5556B95E431CCA8', 'Date': 'Fri, 14 Dec 2018 19:06:40 GMT', 'x-amz-bucket-region': 'us-east-2', 'Content-Type': 'application/xml', 'Transfer-Encoding': 'chunked', 'Server': 'AmazonS3'}"}
# {"message": "Response headers: {'x-amz-id-2': 'TrkXI9rge0KJy+wVICwUfQAA5KlU5u8B98N8FegMqGYacUpn+4NnGpAkkpUgGdr9pbyruUjvcUQ=', 'x-amz-request-id': 'D5556B95E431CCA8', 'Date': 'Fri, 14 Dec 2018 19:06:40 GMT', 'x-amz-bucket-region': 'us-east-2', 'Content-Type': 'application/xml', 'Transfer-Encoding': 'chunked', 'Server': 'AmazonS3'}"}
# {"message": "Response body:\nb''"}
# {"message": "Response body:\nb''"}
# {"message": "Event needs-retry.s3.HeadBucket: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "Event needs-retry.s3.HeadBucket: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "No retry needed."}
# {"message": "No retry needed."}
# {"message": "Event needs-retry.s3.HeadBucket: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event needs-retry.s3.HeadBucket: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "S3 request was previously redirected, not redirecting."}
# {"message": "S3 request was previously redirected, not redirecting."}
# {"message": "S3 client configured for region us-east-1 but the bucket testntest is in region us-east-2; Please configure the proper region to avoid multiple unnecessary redirects and signing attempts."}
# {"message": "S3 client configured for region us-east-1 but the bucket testntest is in region us-east-2; Please configure the proper region to avoid multiple unnecessary redirects and signing attempts."}
# {"message": "Updating URI from https://s3.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv to https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "Updating URI from https://s3.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv to https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "Response received to retry, sleeping for 0 seconds"}
# {"message": "Response received to retry, sleeping for 0 seconds"}
# {"message": "Event request-created.s3.HeadObject: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.HeadObject: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event request-created.s3.HeadObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.HeadObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event choose-signer.s3.HeadObject: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event before-sign.s3.HeadObject: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Event before-sign.s3.HeadObject: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Checking for DNS compatible bucket for: https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "Checking for DNS compatible bucket for: https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "URI updated to: https://testntest.s3.us-east-2.amazonaws.com/nba_2017_endorsement_full_stats.csv"}
# {"message": "URI updated to: https://testntest.s3.us-east-2.amazonaws.com/nba_2017_endorsement_full_stats.csv"}
# {"message": "Calculating signature using v4 auth."}
# {"message": "Calculating signature using v4 auth."}
# {"message": "CanonicalRequest:\nHEAD\n/nba_2017_endorsement_full_stats.csv\n\nhost:testntest.s3.us-east-2.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190639Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "CanonicalRequest:\nHEAD\n/nba_2017_endorsement_full_stats.csv\n\nhost:testntest.s3.us-east-2.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190639Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190639Z\n20181214/us-east-2/s3/aws4_request\neb0c92849dfd44b981e88b39e8c9a0902c387dba4f88c7df0487a9cb9c53c456"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190639Z\n20181214/us-east-2/s3/aws4_request\neb0c92849dfd44b981e88b39e8c9a0902c387dba4f88c7df0487a9cb9c53c456"}
# {"message": "Signature:\n69c32ba74cc83cb2e6ebca4e2d7f48fa012a70988c578d8ea3112117cc81f56d"}
# {"message": "Signature:\n69c32ba74cc83cb2e6ebca4e2d7f48fa012a70988c578d8ea3112117cc81f56d"}
# {"message": "Event request-created.s3.HeadObject: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Event request-created.s3.HeadObject: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://testntest.s3.us-east-2.amazonaws.com/nba_2017_endorsement_full_stats.csv, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190639Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-2/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=69c32ba74cc83cb2e6ebca4e2d7f48fa012a70988c578d8ea3112117cc81f56d'}>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=HEAD, url=https://testntest.s3.us-east-2.amazonaws.com/nba_2017_endorsement_full_stats.csv, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190639Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-2/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=69c32ba74cc83cb2e6ebca4e2d7f48fa012a70988c578d8ea3112117cc81f56d'}>"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Starting new HTTPS connection (2): testntest.s3.us-east-2.amazonaws.com"}
# {"message": "Starting new HTTPS connection (2): testntest.s3.us-east-2.amazonaws.com"}
# {"message": "https://testntest.s3.us-east-2.amazonaws.com:443 \"HEAD /nba_2017_endorsement_full_stats.csv HTTP/1.1\" 200 0"}
# {"message": "https://testntest.s3.us-east-2.amazonaws.com:443 \"HEAD /nba_2017_endorsement_full_stats.csv HTTP/1.1\" 200 0"}
# {"message": "Response headers: {'x-amz-id-2': 'O2LxC3y1e7b9U6TdAD21AtaVybEiTaqedFKWg0/Lfn7V2PYA0sD0PjGfIosDZFv9DHEXg9KGL/0=', 'x-amz-request-id': 'AFB111AF0C49CA92', 'Date': 'Fri, 14 Dec 2018 19:06:41 GMT', 'Last-Modified': 'Wed, 29 Nov 2017 18:48:35 GMT', 'ETag': '\"60ea033c62d2b044f596333cd464baa3\"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/csv', 'Content-Length': '1447', 'Server': 'AmazonS3'}"}
# {"message": "Response headers: {'x-amz-id-2': 'O2LxC3y1e7b9U6TdAD21AtaVybEiTaqedFKWg0/Lfn7V2PYA0sD0PjGfIosDZFv9DHEXg9KGL/0=', 'x-amz-request-id': 'AFB111AF0C49CA92', 'Date': 'Fri, 14 Dec 2018 19:06:41 GMT', 'Last-Modified': 'Wed, 29 Nov 2017 18:48:35 GMT', 'ETag': '\"60ea033c62d2b044f596333cd464baa3\"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/csv', 'Content-Length': '1447', 'Server': 'AmazonS3'}"}
# {"message": "Response body:\nb''"}
# {"message": "Response body:\nb''"}
# {"message": "Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "No retry needed."}
# {"message": "No retry needed."}
# {"message": "Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "S3 request was previously redirected, not redirecting."}
# {"message": "S3 request was previously redirected, not redirecting."}
# {"message": "Submitting task ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'extra_args': {}}) to executor <s3transfer.futures.BoundedExecutor object at 0x7f8fb4a63668> for transfer request: 0."}
# {"message": "Submitting task ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'extra_args': {}}) to executor <s3transfer.futures.BoundedExecutor object at 0x7f8fb4a63668> for transfer request: 0."}
# {"message": "Acquiring 0"}
# {"message": "Acquiring 0"}
# {"message": "ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'extra_args': {}}) about to wait for the following futures []"}
# {"message": "Releasing acquire 0/None"}
# {"message": "ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'extra_args': {}}) about to wait for the following futures []"}
# {"message": "Releasing acquire 0/None"}
# {"message": "ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'extra_args': {}}) done waiting for dependent futures"}
# {"message": "ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'extra_args': {}}) done waiting for dependent futures"}
# {"message": "Executing task ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'extra_args': {}}) with kwargs {'client': <botocore.client.S3 object at 0x7f8fb4b36978>, 'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x7f8fb4a74c88>, 'extra_args': {}, 'callbacks': [], 'max_attempts': 5, 'download_output_manager': <s3transfer.download.DownloadFilenameOutputManager object at 0x7f8fb4a74b70>, 'io_chunksize': 262144, 'bandwidth_limiter': None}"}
# {"message": "Executing task ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'extra_args': {}}) with kwargs {'client': <botocore.client.S3 object at 0x7f8fb4b36978>, 'bucket': 'testntest', 'key': 'nba_2017_endorsement_full_stats.csv', 'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x7f8fb4a74c88>, 'extra_args': {}, 'callbacks': [], 'max_attempts': 5, 'download_output_manager': <s3transfer.download.DownloadFilenameOutputManager object at 0x7f8fb4a74b70>, 'io_chunksize': 262144, 'bandwidth_limiter': None}"}
# {"message": "Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7f8fb5860400>"}
# {"message": "Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7f8fb5860400>"}
# {"message": "Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7f8fb5860378>"}
# {"message": "Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7f8fb5860378>"}
# {"message": "Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7f8fb5860840>"}
# {"message": "Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7f8fb5860840>"}
# {"message": "Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Updating URI from https://s3.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv to https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "Updating URI from https://s3.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv to https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "Making request for OperationModel(name=GetObject) with params: {'url_path': '/testntest/nba_2017_endorsement_full_stats.csv', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource'}, 'body': b'', 'url': 'https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb4b36c18>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'region': 'us-east-2', 'bucket': 'testntest', 'endpoint': 'https://s3.us-east-2.amazonaws.com'}}}"}
# {"message": "Making request for OperationModel(name=GetObject) with params: {'url_path': '/testntest/nba_2017_endorsement_full_stats.csv', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource'}, 'body': b'', 'url': 'https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb4b36c18>, 'has_streaming_input': False, 'auth_type': None, 'signing': {'region': 'us-east-2', 'bucket': 'testntest', 'endpoint': 'https://s3.us-east-2.amazonaws.com'}}}"}
# {"message": "Event request-created.s3.GetObject: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.GetObject: calling handler <function signal_not_transferring at 0x7f8fb4aea268>"}
# {"message": "Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb4b49320>>"}
# {"message": "Event choose-signer.s3.GetObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.GetObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x7f8fb4ca77f0>>"}
# {"message": "Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event before-sign.s3.GetObject: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Event before-sign.s3.GetObject: calling handler <function fix_s3_host at 0x7f8fb598b488>"}
# {"message": "Checking for DNS compatible bucket for: https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "Checking for DNS compatible bucket for: https://s3.us-east-2.amazonaws.com/testntest/nba_2017_endorsement_full_stats.csv"}
# {"message": "URI updated to: https://testntest.s3.us-east-2.amazonaws.com/nba_2017_endorsement_full_stats.csv"}
# {"message": "URI updated to: https://testntest.s3.us-east-2.amazonaws.com/nba_2017_endorsement_full_stats.csv"}
# {"message": "Calculating signature using v4 auth."}
# {"message": "Calculating signature using v4 auth."}
# {"message": "CanonicalRequest:\nGET\n/nba_2017_endorsement_full_stats.csv\n\nhost:testntest.s3.us-east-2.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190640Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "CanonicalRequest:\nGET\n/nba_2017_endorsement_full_stats.csv\n\nhost:testntest.s3.us-east-2.amazonaws.com\nx-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855\nx-amz-date:20181214T190640Z\n\nhost;x-amz-content-sha256;x-amz-date\ne3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190640Z\n20181214/us-east-2/s3/aws4_request\n2e243a8c95b06e393be0f7c32cee241b83423b3231c92471266e365180a3de6b"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T190640Z\n20181214/us-east-2/s3/aws4_request\n2e243a8c95b06e393be0f7c32cee241b83423b3231c92471266e365180a3de6b"}
# {"message": "Signature:\n7c748447a0a1a146d02b3995e18ef7f34c3aa47150d51253f043c6161992ca7e"}
# {"message": "Signature:\n7c748447a0a1a146d02b3995e18ef7f34c3aa47150d51253f043c6161992ca7e"}
# {"message": "Event request-created.s3.GetObject: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Event request-created.s3.GetObject: calling handler <function signal_transferring at 0x7f8fb4aea2f0>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://testntest.s3.us-east-2.amazonaws.com/nba_2017_endorsement_full_stats.csv, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190640Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-2/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=7c748447a0a1a146d02b3995e18ef7f34c3aa47150d51253f043c6161992ca7e'}>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://testntest.s3.us-east-2.amazonaws.com/nba_2017_endorsement_full_stats.csv, headers={'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62 Resource', 'X-Amz-Date': b'20181214T190640Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-2/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=7c748447a0a1a146d02b3995e18ef7f34c3aa47150d51253f043c6161992ca7e'}>"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "https://testntest.s3.us-east-2.amazonaws.com:443 \"GET /nba_2017_endorsement_full_stats.csv HTTP/1.1\" 200 1447"}
# {"message": "https://testntest.s3.us-east-2.amazonaws.com:443 \"GET /nba_2017_endorsement_full_stats.csv HTTP/1.1\" 200 1447"}
# {"message": "Response headers: {'x-amz-id-2': 'OzI+sE1ZbetaaRTj+pWA6nPuNi0e1yrAUi1vKcvSShsXqP+LxiQTI5c3pV5y1pT6B4RR06dRBrg=', 'x-amz-request-id': '9763AE9849C42E10', 'Date': 'Fri, 14 Dec 2018 19:06:41 GMT', 'Last-Modified': 'Wed, 29 Nov 2017 18:48:35 GMT', 'ETag': '\"60ea033c62d2b044f596333cd464baa3\"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/csv', 'Content-Length': '1447', 'Server': 'AmazonS3'}"}
# {"message": "Response headers: {'x-amz-id-2': 'OzI+sE1ZbetaaRTj+pWA6nPuNi0e1yrAUi1vKcvSShsXqP+LxiQTI5c3pV5y1pT6B4RR06dRBrg=', 'x-amz-request-id': '9763AE9849C42E10', 'Date': 'Fri, 14 Dec 2018 19:06:41 GMT', 'Last-Modified': 'Wed, 29 Nov 2017 18:48:35 GMT', 'ETag': '\"60ea033c62d2b044f596333cd464baa3\"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/csv', 'Content-Length': '1447', 'Server': 'AmazonS3'}"}
# {"message": "Response body:\n<botocore.response.StreamingBody object at 0x7f8fb4229748>"}
# {"message": "Response body:\n<botocore.response.StreamingBody object at 0x7f8fb4229748>"}
# {"message": "Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4ab6470>"}
# {"message": "No retry needed."}
# {"message": "No retry needed."}
# {"message": "Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7f8fb4ab62e8>>"}
# {"message": "IOWriteTask(transfer_id=0, {'offset': 0}) about to wait for the following futures []"}
# {"message": "IOWriteTask(transfer_id=0, {'offset': 0}) about to wait for the following futures []"}
# {"message": "IOWriteTask(transfer_id=0, {'offset': 0}) done waiting for dependent futures"}
# {"message": "IOWriteTask(transfer_id=0, {'offset': 0}) done waiting for dependent futures"}
# {"message": "Executing task IOWriteTask(transfer_id=0, {'offset': 0}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x7f8fb4a74c88>, 'offset': 0}"}
# {"message": "Executing task IOWriteTask(transfer_id=0, {'offset': 0}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x7f8fb4a74c88>, 'offset': 0}"}
# {"message": "IORenameFileTask(transfer_id=0, {'final_filename': '/tmp/nba_2017_endorsement_full_stats.csv'}) about to wait for the following futures []"}
# {"message": "IORenameFileTask(transfer_id=0, {'final_filename': '/tmp/nba_2017_endorsement_full_stats.csv'}) about to wait for the following futures []"}
# {"message": "IORenameFileTask(transfer_id=0, {'final_filename': '/tmp/nba_2017_endorsement_full_stats.csv'}) done waiting for dependent futures"}
# {"message": "IORenameFileTask(transfer_id=0, {'final_filename': '/tmp/nba_2017_endorsement_full_stats.csv'}) done waiting for dependent futures"}
# {"message": "Executing task IORenameFileTask(transfer_id=0, {'final_filename': '/tmp/nba_2017_endorsement_full_stats.csv'}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x7f8fb4a74c88>, 'final_filename': '/tmp/nba_2017_endorsement_full_stats.csv', 'osutil': <s3transfer.utils.OSUtils object at 0x7f8fb4a63470>}"}
# {"message": "Executing task IORenameFileTask(transfer_id=0, {'final_filename': '/tmp/nba_2017_endorsement_full_stats.csv'}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x7f8fb4a74c88>, 'final_filename': '/tmp/nba_2017_endorsement_full_stats.csv', 'osutil': <s3transfer.utils.OSUtils object at 0x7f8fb4a63470>}"}
# {"message": "Releasing acquire 0/None"}
# {"message": "Releasing acquire 0/None"}

# %%
# !ls -l /tmp
# Out:
# total 4
# srw------- 1 root root    0 Dec 14 16:11 drivefs_ipc.0
# srw------- 1 root root    0 Dec 14 16:11 drivefs_ipc.0_shell
# -rw-r--r-- 1 root root 1447 Dec 14 19:06 nba_2017_endorsement_full_stats.csv

# %% [markdown]
# ### Pandas

# %% [markdown]
# Main Datascience library for AWS and Python
#
#
#
# *   It is assumed you know about it
# *   Many study videos will show examples using it

# %%
import pandas as pd

df = pd.read_csv("/tmp/nba_2017_endorsement_full_stats.csv")
df.head(2)
# Out:
#          PLAYER                   TEAM  SALARY_MILLIONS  ENDORSEMENT_MILLIONS  \
# 0  LeBron James    Cleveland Cavaliers            30.96                  55.0
# 1  Kevin Durant  Golden State Warriors            26.50                  36.0
#
#    PCT_ATTENDANCE_STADIUM  ATTENDANCE_TOTAL_BY_10K  \
# 0                   100.0                     84.0
# 1                   100.0                     80.0
#
#    FRANCHISE_VALUE_100_MILLION  ELO_100X  CONF POSITION  AGE    MP    GP  \
# 0                         12.0     15.45  East       SF   32  37.8  74.0
# 1                         26.0     17.70  West       SF   28  33.4  62.0
#
#     MPG  WINS_RPM  PLAYER_TEAM_WINS  WIKIPEDIA_PAGEVIEWS_10K  \
# 0  37.8     20.43              51.0                    14.70
# 1  33.4     12.24              51.0                     6.29
#
#    TWITTER_FAVORITE_COUNT_1K
# 0                       5.53
# 1                       1.43

# %% [markdown]
# #### Descriptive Statistics with Pandas

# %%
df.describe()
# Out:
#        SALARY_MILLIONS  ENDORSEMENT_MILLIONS  PCT_ATTENDANCE_STADIUM  \
# count        10.000000             10.000000               10.000000
# mean         23.216000             21.700000               99.800000
# std           5.294438             15.362653                2.394438
# min          12.110000              8.000000               94.000000
# 25%          21.707500             13.000000              100.000000
# 50%          23.880000             14.500000              100.000000
# 75%          26.500000             31.250000              100.000000
# max          30.960000             55.000000              104.000000
#
#        ATTENDANCE_TOTAL_BY_10K  FRANCHISE_VALUE_100_MILLION   ELO_100X  \
# count                10.000000                    10.000000  10.000000
# mean                 80.200000                    21.375000  15.678000
# std                   5.202563                     8.507554   1.361142
# min                  70.000000                    10.250000  13.740000
# 25%                  78.500000                    13.125000  15.250000
# 50%                  80.500000                    22.500000  15.450000
# 75%                  83.250000                    26.000000  16.275000
# max                  89.000000                    33.000000  17.700000
#
#              AGE         MP         GP        MPG   WINS_RPM  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   29.300000  33.890000  70.800000  33.890000  11.506000
# std     3.164034   2.303837   8.390471   2.303837   6.868487
# min    24.000000  29.900000  60.000000  29.900000   1.170000
# 25%    28.000000  32.725000  62.500000  32.725000   6.015000
# 50%    28.000000  33.850000  73.000000  33.850000  12.860000
# 75%    31.750000  34.975000  77.750000  34.975000  16.890000
# max    35.000000  37.800000  81.000000  37.800000  20.430000
#
#        PLAYER_TEAM_WINS  WIKIPEDIA_PAGEVIEWS_10K  TWITTER_FAVORITE_COUNT_1K
# count         10.000000                10.000000                  10.000000
# mean          44.100000                 6.532000                   2.764000
# std           12.591443                 5.204233                   3.646399
# min           26.000000                 2.690000                   0.350000
# 25%           32.500000                 3.402500                   0.865000
# 50%           46.500000                 4.475000                   1.485000
# 75%           51.000000                 5.917500                   2.062500
# max           65.000000                17.570000                  12.280000

# %% [markdown]
# ### Plotting with Python

# %%
import warnings
import numpy as np
warnings.simplefilter('ignore', np.RankWarning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fig.set_size_inches(11, 8.5)
sns.regplot(data=df, 
            x="SALARY_MILLIONS", y="ENDORSEMENT_MILLIONS", 
            order=2).set_title("NBA Salary & Endorsements")
# Out:
# Text(0.5,1,'NBA Salary & Endorsements')

# %% [markdown]
# ### Putting it all together (Production Style)

# %%
# !pip -q install python-json-logger

# %%
import logging
from pythonjsonlogger import jsonlogger

LOG = logging.getLogger()
LOG.setLevel(logging.DEBUG)
logHandler = logging.StreamHandler()
formatter = jsonlogger.JsonFormatter()
logHandler.setFormatter(formatter)
LOG.addHandler(logHandler)

import click
import boto3
import pandas as pd

TEST_DF = pd.DataFrame(
    {"SentimentRaw": ["I am very Angry",
                    "We are very Happy",
                    "It is raining in Seattle"]}
)

def create_sentiment(row):
    """Uses AWS Comprehend to Create Sentiments on a DataFrame"""

    LOG.info(f"Processing {row}")
    comprehend = boto3.client(service_name='comprehend', region_name="us-east-1")
    payload = comprehend.detect_sentiment(Text=row, LanguageCode='en')
    LOG.debug(f"Found Sentiment: {payload}")    
    sentiment = payload['Sentiment']
    return sentiment

def apply_sentiment(df, column="SentimentRaw"):
    """Uses Pandas Apply to Create Sentiment Analysis"""

    df['Sentiment'] = df[column].apply(create_sentiment)
    return df

# %%
df = apply_sentiment(TEST_DF)
# Out:
# {"message": "Processing I am very Angry"}
# {"message": "Processing I am very Angry"}
# {"message": "Event choose-service-name: calling handler <function handle_service_name_alias at 0x7f8fb5845950>"}
# {"message": "Event choose-service-name: calling handler <function handle_service_name_alias at 0x7f8fb5845950>"}
# {"message": "Event creating-client-class.comprehend: calling handler <function add_generate_presigned_url at 0x7f8fb588f378>"}
# {"message": "Event creating-client-class.comprehend: calling handler <function add_generate_presigned_url at 0x7f8fb588f378>"}
# {"message": "The s3 config key is not a dictionary type, ignoring its value of: None"}
# {"message": "The s3 config key is not a dictionary type, ignoring its value of: None"}
# {"message": "Setting comprehend timeout as (60, 60)"}
# {"message": "Setting comprehend timeout as (60, 60)"}
# {"message": "Registering retry handlers for service: comprehend"}
# {"message": "Registering retry handlers for service: comprehend"}
# {"message": "Event before-parameter-build.comprehend.DetectSentiment: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-parameter-build.comprehend.DetectSentiment: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Making request for OperationModel(name=DetectSentiment) with params: {'url_path': '/', 'query_string': '', 'method': 'POST', 'headers': {'X-Amz-Target': 'Comprehend_20171127.DetectSentiment', 'Content-Type': 'application/x-amz-json-1.1', 'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62'}, 'body': b'{\"Text\": \"I am very Angry\", \"LanguageCode\": \"en\"}', 'url': 'https://comprehend.us-east-1.amazonaws.com/', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb4ad7a90>, 'has_streaming_input': False, 'auth_type': None}}"}
# {"message": "Making request for OperationModel(name=DetectSentiment) with params: {'url_path': '/', 'query_string': '', 'method': 'POST', 'headers': {'X-Amz-Target': 'Comprehend_20171127.DetectSentiment', 'Content-Type': 'application/x-amz-json-1.1', 'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62'}, 'body': b'{\"Text\": \"I am very Angry\", \"LanguageCode\": \"en\"}', 'url': 'https://comprehend.us-east-1.amazonaws.com/', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb4ad7a90>, 'has_streaming_input': False, 'auth_type': None}}"}
# {"message": "Event request-created.comprehend.DetectSentiment: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fdcbcacf8>>"}
# {"message": "Event request-created.comprehend.DetectSentiment: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fdcbcacf8>>"}
# {"message": "Event choose-signer.comprehend.DetectSentiment: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event choose-signer.comprehend.DetectSentiment: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Calculating signature using v4 auth."}
# {"message": "Calculating signature using v4 auth."}
# {"message": "CanonicalRequest:\nPOST\n/\n\ncontent-type:application/x-amz-json-1.1\nhost:comprehend.us-east-1.amazonaws.com\nx-amz-date:20181214T191117Z\nx-amz-target:Comprehend_20171127.DetectSentiment\n\ncontent-type;host;x-amz-date;x-amz-target\nb1ef9199f866771fdabb0892b573595803acef305db24bf350d5760aa6c2f6e7"}
# {"message": "CanonicalRequest:\nPOST\n/\n\ncontent-type:application/x-amz-json-1.1\nhost:comprehend.us-east-1.amazonaws.com\nx-amz-date:20181214T191117Z\nx-amz-target:Comprehend_20171127.DetectSentiment\n\ncontent-type;host;x-amz-date;x-amz-target\nb1ef9199f866771fdabb0892b573595803acef305db24bf350d5760aa6c2f6e7"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T191117Z\n20181214/us-east-1/comprehend/aws4_request\n5a70db68e9d413b021183cfd1ac3a59e787b866609bacbea09a0abc708a03680"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T191117Z\n20181214/us-east-1/comprehend/aws4_request\n5a70db68e9d413b021183cfd1ac3a59e787b866609bacbea09a0abc708a03680"}
# {"message": "Signature:\n476aa1dc7e2323eb3ffa5861a6c87660c170157a4424d5bb9fd49bc2bb1db321"}
# {"message": "Signature:\n476aa1dc7e2323eb3ffa5861a6c87660c170157a4424d5bb9fd49bc2bb1db321"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=POST, url=https://comprehend.us-east-1.amazonaws.com/, headers={'X-Amz-Target': b'Comprehend_20171127.DetectSentiment', 'Content-Type': b'application/x-amz-json-1.1', 'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62', 'X-Amz-Date': b'20181214T191117Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/comprehend/aws4_request, SignedHeaders=content-type;host;x-amz-date;x-amz-target, Signature=476aa1dc7e2323eb3ffa5861a6c87660c170157a4424d5bb9fd49bc2bb1db321', 'Content-Length': '49'}>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=POST, url=https://comprehend.us-east-1.amazonaws.com/, headers={'X-Amz-Target': b'Comprehend_20171127.DetectSentiment', 'Content-Type': b'application/x-amz-json-1.1', 'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62', 'X-Amz-Date': b'20181214T191117Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/comprehend/aws4_request, SignedHeaders=content-type;host;x-amz-date;x-amz-target, Signature=476aa1dc7e2323eb3ffa5861a6c87660c170157a4424d5bb9fd49bc2bb1db321', 'Content-Length': '49'}>"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Starting new HTTPS connection (1): comprehend.us-east-1.amazonaws.com"}
# {"message": "Starting new HTTPS connection (1): comprehend.us-east-1.amazonaws.com"}
# {"message": "https://comprehend.us-east-1.amazonaws.com:443 \"POST / HTTP/1.1\" 200 166"}
# {"message": "https://comprehend.us-east-1.amazonaws.com:443 \"POST / HTTP/1.1\" 200 166"}
# {"message": "Response headers: {'Date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'Content-Type': 'application/x-amz-json-1.1', 'Content-Length': '166', 'Connection': 'keep-alive', 'x-amzn-RequestId': '0850c2a4-ffd4-11e8-9915-fbeda43b2a4c'}"}
# {"message": "Response headers: {'Date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'Content-Type': 'application/x-amz-json-1.1', 'Content-Length': '166', 'Connection': 'keep-alive', 'x-amzn-RequestId': '0850c2a4-ffd4-11e8-9915-fbeda43b2a4c'}"}
# {"message": "Response body:\nb'{\"Sentiment\":\"NEGATIVE\",\"SentimentScore\":{\"Mixed\":0.014898190274834633,\"Negative\":0.9444955587387085,\"Neutral\":0.036787811666727066,\"Positive\":0.0038184858858585358}}'"}
# {"message": "Response body:\nb'{\"Sentiment\":\"NEGATIVE\",\"SentimentScore\":{\"Mixed\":0.014898190274834633,\"Negative\":0.9444955587387085,\"Neutral\":0.036787811666727066,\"Positive\":0.0038184858858585358}}'"}
# {"message": "Event needs-retry.comprehend.DetectSentiment: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4a63908>"}
# {"message": "Event needs-retry.comprehend.DetectSentiment: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb4a63908>"}
# {"message": "No retry needed."}
# {"message": "No retry needed."}
# {"message": "Found Sentiment: {'Sentiment': 'NEGATIVE', 'SentimentScore': {'Positive': 0.0038184858858585358, 'Negative': 0.9444955587387085, 'Neutral': 0.036787811666727066, 'Mixed': 0.014898190274834633}, 'ResponseMetadata': {'RequestId': '0850c2a4-ffd4-11e8-9915-fbeda43b2a4c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'content-type': 'application/x-amz-json-1.1', 'content-length': '166', 'connection': 'keep-alive', 'x-amzn-requestid': '0850c2a4-ffd4-11e8-9915-fbeda43b2a4c'}, 'RetryAttempts': 0}}"}
# {"message": "Found Sentiment: {'Sentiment': 'NEGATIVE', 'SentimentScore': {'Positive': 0.0038184858858585358, 'Negative': 0.9444955587387085, 'Neutral': 0.036787811666727066, 'Mixed': 0.014898190274834633}, 'ResponseMetadata': {'RequestId': '0850c2a4-ffd4-11e8-9915-fbeda43b2a4c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'content-type': 'application/x-amz-json-1.1', 'content-length': '166', 'connection': 'keep-alive', 'x-amzn-requestid': '0850c2a4-ffd4-11e8-9915-fbeda43b2a4c'}, 'RetryAttempts': 0}}"}
# {"message": "Processing We are very Happy"}
# {"message": "Processing We are very Happy"}
# {"message": "Event choose-service-name: calling handler <function handle_service_name_alias at 0x7f8fb5845950>"}
# {"message": "Event choose-service-name: calling handler <function handle_service_name_alias at 0x7f8fb5845950>"}
# {"message": "Event creating-client-class.comprehend: calling handler <function add_generate_presigned_url at 0x7f8fb588f378>"}
# {"message": "Event creating-client-class.comprehend: calling handler <function add_generate_presigned_url at 0x7f8fb588f378>"}
# {"message": "The s3 config key is not a dictionary type, ignoring its value of: None"}
# {"message": "The s3 config key is not a dictionary type, ignoring its value of: None"}
# {"message": "Setting comprehend timeout as (60, 60)"}
# {"message": "Setting comprehend timeout as (60, 60)"}
# {"message": "Registering retry handlers for service: comprehend"}
# {"message": "Registering retry handlers for service: comprehend"}
# {"message": "Event before-parameter-build.comprehend.DetectSentiment: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-parameter-build.comprehend.DetectSentiment: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Making request for OperationModel(name=DetectSentiment) with params: {'url_path': '/', 'query_string': '', 'method': 'POST', 'headers': {'X-Amz-Target': 'Comprehend_20171127.DetectSentiment', 'Content-Type': 'application/x-amz-json-1.1', 'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62'}, 'body': b'{\"Text\": \"We are very Happy\", \"LanguageCode\": \"en\"}', 'url': 'https://comprehend.us-east-1.amazonaws.com/', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb424c0f0>, 'has_streaming_input': False, 'auth_type': None}}"}
# {"message": "Making request for OperationModel(name=DetectSentiment) with params: {'url_path': '/', 'query_string': '', 'method': 'POST', 'headers': {'X-Amz-Target': 'Comprehend_20171127.DetectSentiment', 'Content-Type': 'application/x-amz-json-1.1', 'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62'}, 'body': b'{\"Text\": \"We are very Happy\", \"LanguageCode\": \"en\"}', 'url': 'https://comprehend.us-east-1.amazonaws.com/', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb424c0f0>, 'has_streaming_input': False, 'auth_type': None}}"}
# {"message": "Event request-created.comprehend.DetectSentiment: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb424c198>>"}
# {"message": "Event request-created.comprehend.DetectSentiment: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb424c198>>"}
# {"message": "Event choose-signer.comprehend.DetectSentiment: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event choose-signer.comprehend.DetectSentiment: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Calculating signature using v4 auth."}
# {"message": "Calculating signature using v4 auth."}
# {"message": "CanonicalRequest:\nPOST\n/\n\ncontent-type:application/x-amz-json-1.1\nhost:comprehend.us-east-1.amazonaws.com\nx-amz-date:20181214T191117Z\nx-amz-target:Comprehend_20171127.DetectSentiment\n\ncontent-type;host;x-amz-date;x-amz-target\n3fcc4fd7f43751f3acd87a81645d215bb731eb0f7034f6eebd85d6181bbbf2ed"}
# {"message": "CanonicalRequest:\nPOST\n/\n\ncontent-type:application/x-amz-json-1.1\nhost:comprehend.us-east-1.amazonaws.com\nx-amz-date:20181214T191117Z\nx-amz-target:Comprehend_20171127.DetectSentiment\n\ncontent-type;host;x-amz-date;x-amz-target\n3fcc4fd7f43751f3acd87a81645d215bb731eb0f7034f6eebd85d6181bbbf2ed"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T191117Z\n20181214/us-east-1/comprehend/aws4_request\nd9092213dca760515c3447dfa2ece752b8854b6d9486fef41364bbec5e71f10d"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T191117Z\n20181214/us-east-1/comprehend/aws4_request\nd9092213dca760515c3447dfa2ece752b8854b6d9486fef41364bbec5e71f10d"}
# {"message": "Signature:\n4780d896cc51a51f85ee8efc83a300cca1ec2ee4e89b7ca4ba6e5edb84acdd0a"}
# {"message": "Signature:\n4780d896cc51a51f85ee8efc83a300cca1ec2ee4e89b7ca4ba6e5edb84acdd0a"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=POST, url=https://comprehend.us-east-1.amazonaws.com/, headers={'X-Amz-Target': b'Comprehend_20171127.DetectSentiment', 'Content-Type': b'application/x-amz-json-1.1', 'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62', 'X-Amz-Date': b'20181214T191117Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/comprehend/aws4_request, SignedHeaders=content-type;host;x-amz-date;x-amz-target, Signature=4780d896cc51a51f85ee8efc83a300cca1ec2ee4e89b7ca4ba6e5edb84acdd0a', 'Content-Length': '51'}>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=POST, url=https://comprehend.us-east-1.amazonaws.com/, headers={'X-Amz-Target': b'Comprehend_20171127.DetectSentiment', 'Content-Type': b'application/x-amz-json-1.1', 'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62', 'X-Amz-Date': b'20181214T191117Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/comprehend/aws4_request, SignedHeaders=content-type;host;x-amz-date;x-amz-target, Signature=4780d896cc51a51f85ee8efc83a300cca1ec2ee4e89b7ca4ba6e5edb84acdd0a', 'Content-Length': '51'}>"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Starting new HTTPS connection (1): comprehend.us-east-1.amazonaws.com"}
# {"message": "Starting new HTTPS connection (1): comprehend.us-east-1.amazonaws.com"}
# {"message": "https://comprehend.us-east-1.amazonaws.com:443 \"POST / HTTP/1.1\" 200 166"}
# {"message": "https://comprehend.us-east-1.amazonaws.com:443 \"POST / HTTP/1.1\" 200 166"}
# {"message": "Response headers: {'Date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'Content-Type': 'application/x-amz-json-1.1', 'Content-Length': '166', 'Connection': 'keep-alive', 'x-amzn-RequestId': '086d998c-ffd4-11e8-983f-d98c2036a672'}"}
# {"message": "Response headers: {'Date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'Content-Type': 'application/x-amz-json-1.1', 'Content-Length': '166', 'Connection': 'keep-alive', 'x-amzn-RequestId': '086d998c-ffd4-11e8-983f-d98c2036a672'}"}
# {"message": "Response body:\nb'{\"Sentiment\":\"POSITIVE\",\"SentimentScore\":{\"Mixed\":0.0020924475975334644,\"Negative\":6.253701285459101E-4,\"Neutral\":0.011492948047816753,\"Positive\":0.9857891201972961}}'"}
# {"message": "Response body:\nb'{\"Sentiment\":\"POSITIVE\",\"SentimentScore\":{\"Mixed\":0.0020924475975334644,\"Negative\":6.253701285459101E-4,\"Neutral\":0.011492948047816753,\"Positive\":0.9857891201972961}}'"}
# {"message": "Event needs-retry.comprehend.DetectSentiment: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb424c630>"}
# {"message": "Event needs-retry.comprehend.DetectSentiment: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb424c630>"}
# {"message": "No retry needed."}
# {"message": "No retry needed."}
# {"message": "Found Sentiment: {'Sentiment': 'POSITIVE', 'SentimentScore': {'Positive': 0.9857891201972961, 'Negative': 0.0006253701285459101, 'Neutral': 0.011492948047816753, 'Mixed': 0.0020924475975334644}, 'ResponseMetadata': {'RequestId': '086d998c-ffd4-11e8-983f-d98c2036a672', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'content-type': 'application/x-amz-json-1.1', 'content-length': '166', 'connection': 'keep-alive', 'x-amzn-requestid': '086d998c-ffd4-11e8-983f-d98c2036a672'}, 'RetryAttempts': 0}}"}
# {"message": "Found Sentiment: {'Sentiment': 'POSITIVE', 'SentimentScore': {'Positive': 0.9857891201972961, 'Negative': 0.0006253701285459101, 'Neutral': 0.011492948047816753, 'Mixed': 0.0020924475975334644}, 'ResponseMetadata': {'RequestId': '086d998c-ffd4-11e8-983f-d98c2036a672', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'content-type': 'application/x-amz-json-1.1', 'content-length': '166', 'connection': 'keep-alive', 'x-amzn-requestid': '086d998c-ffd4-11e8-983f-d98c2036a672'}, 'RetryAttempts': 0}}"}
# {"message": "Processing It is raining in Seattle"}
# {"message": "Processing It is raining in Seattle"}
# {"message": "Event choose-service-name: calling handler <function handle_service_name_alias at 0x7f8fb5845950>"}
# {"message": "Event choose-service-name: calling handler <function handle_service_name_alias at 0x7f8fb5845950>"}
# {"message": "Event creating-client-class.comprehend: calling handler <function add_generate_presigned_url at 0x7f8fb588f378>"}
# {"message": "Event creating-client-class.comprehend: calling handler <function add_generate_presigned_url at 0x7f8fb588f378>"}
# {"message": "The s3 config key is not a dictionary type, ignoring its value of: None"}
# {"message": "The s3 config key is not a dictionary type, ignoring its value of: None"}
# {"message": "Setting comprehend timeout as (60, 60)"}
# {"message": "Setting comprehend timeout as (60, 60)"}
# {"message": "Registering retry handlers for service: comprehend"}
# {"message": "Registering retry handlers for service: comprehend"}
# {"message": "Event before-parameter-build.comprehend.DetectSentiment: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Event before-parameter-build.comprehend.DetectSentiment: calling handler <function generate_idempotent_uuid at 0x7f8fb585ff28>"}
# {"message": "Making request for OperationModel(name=DetectSentiment) with params: {'url_path': '/', 'query_string': '', 'method': 'POST', 'headers': {'X-Amz-Target': 'Comprehend_20171127.DetectSentiment', 'Content-Type': 'application/x-amz-json-1.1', 'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62'}, 'body': b'{\"Text\": \"It is raining in Seattle\", \"LanguageCode\": \"en\"}', 'url': 'https://comprehend.us-east-1.amazonaws.com/', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb424d630>, 'has_streaming_input': False, 'auth_type': None}}"}
# {"message": "Making request for OperationModel(name=DetectSentiment) with params: {'url_path': '/', 'query_string': '', 'method': 'POST', 'headers': {'X-Amz-Target': 'Comprehend_20171127.DetectSentiment', 'Content-Type': 'application/x-amz-json-1.1', 'User-Agent': 'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62'}, 'body': b'{\"Text\": \"It is raining in Seattle\", \"LanguageCode\": \"en\"}', 'url': 'https://comprehend.us-east-1.amazonaws.com/', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x7f8fb424d630>, 'has_streaming_input': False, 'auth_type': None}}"}
# {"message": "Event request-created.comprehend.DetectSentiment: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb424d8d0>>"}
# {"message": "Event request-created.comprehend.DetectSentiment: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7f8fb424d8d0>>"}
# {"message": "Event choose-signer.comprehend.DetectSentiment: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Event choose-signer.comprehend.DetectSentiment: calling handler <function set_operation_specific_signer at 0x7f8fb585fe18>"}
# {"message": "Calculating signature using v4 auth."}
# {"message": "Calculating signature using v4 auth."}
# {"message": "CanonicalRequest:\nPOST\n/\n\ncontent-type:application/x-amz-json-1.1\nhost:comprehend.us-east-1.amazonaws.com\nx-amz-date:20181214T191117Z\nx-amz-target:Comprehend_20171127.DetectSentiment\n\ncontent-type;host;x-amz-date;x-amz-target\n2b87023c28eae9359c0e0898cdc5f400f25354b7d43533ade7ab063d9110a253"}
# {"message": "CanonicalRequest:\nPOST\n/\n\ncontent-type:application/x-amz-json-1.1\nhost:comprehend.us-east-1.amazonaws.com\nx-amz-date:20181214T191117Z\nx-amz-target:Comprehend_20171127.DetectSentiment\n\ncontent-type;host;x-amz-date;x-amz-target\n2b87023c28eae9359c0e0898cdc5f400f25354b7d43533ade7ab063d9110a253"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T191117Z\n20181214/us-east-1/comprehend/aws4_request\ne7120918a65113acdea424ee61f651eb8bc5a9172b394d58f02220f0e49d46b0"}
# {"message": "StringToSign:\nAWS4-HMAC-SHA256\n20181214T191117Z\n20181214/us-east-1/comprehend/aws4_request\ne7120918a65113acdea424ee61f651eb8bc5a9172b394d58f02220f0e49d46b0"}
# {"message": "Signature:\n1e40aa6cd8e8d37ba360a6005e2f63260264012f42435c7b115dcedf5c9516ea"}
# {"message": "Signature:\n1e40aa6cd8e8d37ba360a6005e2f63260264012f42435c7b115dcedf5c9516ea"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=POST, url=https://comprehend.us-east-1.amazonaws.com/, headers={'X-Amz-Target': b'Comprehend_20171127.DetectSentiment', 'Content-Type': b'application/x-amz-json-1.1', 'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62', 'X-Amz-Date': b'20181214T191117Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/comprehend/aws4_request, SignedHeaders=content-type;host;x-amz-date;x-amz-target, Signature=1e40aa6cd8e8d37ba360a6005e2f63260264012f42435c7b115dcedf5c9516ea', 'Content-Length': '58'}>"}
# {"message": "Sending http request: <AWSPreparedRequest stream_output=False, method=POST, url=https://comprehend.us-east-1.amazonaws.com/, headers={'X-Amz-Target': b'Comprehend_20171127.DetectSentiment', 'Content-Type': b'application/x-amz-json-1.1', 'User-Agent': b'Boto3/1.9.62 Python/3.6.7 Linux/4.14.65+ Botocore/1.12.62', 'X-Amz-Date': b'20181214T191117Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAICCEUL6RCL57RQGQ/20181214/us-east-1/comprehend/aws4_request, SignedHeaders=content-type;host;x-amz-date;x-amz-target, Signature=1e40aa6cd8e8d37ba360a6005e2f63260264012f42435c7b115dcedf5c9516ea', 'Content-Length': '58'}>"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Converted retries value: False -> Retry(total=False, connect=None, read=None, redirect=0, status=None)"}
# {"message": "Starting new HTTPS connection (1): comprehend.us-east-1.amazonaws.com"}
# {"message": "Starting new HTTPS connection (1): comprehend.us-east-1.amazonaws.com"}
# {"message": "https://comprehend.us-east-1.amazonaws.com:443 \"POST / HTTP/1.1\" 200 161"}
# {"message": "https://comprehend.us-east-1.amazonaws.com:443 \"POST / HTTP/1.1\" 200 161"}
# {"message": "Response headers: {'Date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'Content-Type': 'application/x-amz-json-1.1', 'Content-Length': '161', 'Connection': 'keep-alive', 'x-amzn-RequestId': '08884ccb-ffd4-11e8-85ab-85a3217ced42'}"}
# {"message": "Response headers: {'Date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'Content-Type': 'application/x-amz-json-1.1', 'Content-Length': '161', 'Connection': 'keep-alive', 'x-amzn-RequestId': '08884ccb-ffd4-11e8-85ab-85a3217ced42'}"}
# {"message": "Response body:\nb'{\"Sentiment\":\"NEUTRAL\",\"SentimentScore\":{\"Mixed\":0.01440255343914032,\"Negative\":0.044540803879499435,\"Neutral\":0.5939325094223022,\"Positive\":0.3471241593360901}}'"}
# {"message": "Response body:\nb'{\"Sentiment\":\"NEUTRAL\",\"SentimentScore\":{\"Mixed\":0.01440255343914032,\"Negative\":0.044540803879499435,\"Neutral\":0.5939325094223022,\"Positive\":0.3471241593360901}}'"}
# {"message": "Event needs-retry.comprehend.DetectSentiment: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb424d9e8>"}
# {"message": "Event needs-retry.comprehend.DetectSentiment: calling handler <botocore.retryhandler.RetryHandler object at 0x7f8fb424d9e8>"}
# {"message": "No retry needed."}
# {"message": "No retry needed."}
# {"message": "Found Sentiment: {'Sentiment': 'NEUTRAL', 'SentimentScore': {'Positive': 0.3471241593360901, 'Negative': 0.044540803879499435, 'Neutral': 0.5939325094223022, 'Mixed': 0.01440255343914032}, 'ResponseMetadata': {'RequestId': '08884ccb-ffd4-11e8-85ab-85a3217ced42', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'content-type': 'application/x-amz-json-1.1', 'content-length': '161', 'connection': 'keep-alive', 'x-amzn-requestid': '08884ccb-ffd4-11e8-85ab-85a3217ced42'}, 'RetryAttempts': 0}}"}
# {"message": "Found Sentiment: {'Sentiment': 'NEUTRAL', 'SentimentScore': {'Positive': 0.3471241593360901, 'Negative': 0.044540803879499435, 'Neutral': 0.5939325094223022, 'Mixed': 0.01440255343914032}, 'ResponseMetadata': {'RequestId': '08884ccb-ffd4-11e8-85ab-85a3217ced42', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Fri, 14 Dec 2018 19:11:17 GMT', 'content-type': 'application/x-amz-json-1.1', 'content-length': '161', 'connection': 'keep-alive', 'x-amzn-requestid': '08884ccb-ffd4-11e8-85ab-85a3217ced42'}, 'RetryAttempts': 0}}"}

# %%
df.head()
# Out:
#                SentimentRaw Sentiment
# 0           I am very Angry  NEGATIVE
# 1         We are very Happy  POSITIVE
# 2  It is raining in Seattle   NEUTRAL

# %% [markdown]
# ## 7.5 Cloud9

# %% [markdown]
# *   Web based [development environment](https://docs.aws.amazon.com/cloud9/latest/user-guide/sample-python.html)
#
#
# ![Cloud9](https://user-images.githubusercontent.com/58792/50033517-afe14000-ffad-11e8-894a-f70389a046d7.png)

# %% [markdown]
# ### [Demo]Cloud9

# %% [markdown]
# *   Create a cloud9 environment
# *   Install Python 3.6
#
# ---
#
#
#
# ```bash
# sudo yum -y update
# sudo yum -y install python36
#
# ```

# %% [markdown]
# **Python Lambda Function**
#
# ```python
# import json
# import decimal
#
#
# def lambda_handler(event, context):
#
#   print(event)
#   if 'body' in event:
#     event = json.loads(event["body"])
#
#   amount = float(event["amount"])
#   res = []
#   coins = [1,5,10,25]
#   coin_lookup = {25: "quarters", 10: "dimes", 5: "nickels", 1: "pennies"}
#   coin = coins.pop()
#   num, rem  = divmod(int(amount*100), coin)
#   res.append({num:coin_lookup[coin]})
#   while rem > 0:
#     coin = coins.pop()
#     num, rem = divmod(rem, coin)
#     if num:
#       if coin in coin_lookup:
#         res.append({num:coin_lookup[coin]})
#
#   response = {
#     "statusCode": "200",
#     "headers": { "Content-type": "application/json" },
#     "body": json.dumps({"res": res})
#   }
#
#   return response
# ```

# %% [markdown]
# **payload**
#
#
#
# ```javascript
# {"amount": ".71"}
# ```

# %% [markdown]
# **response**
#
#
#
# ```javascript
# Response
# {
#     "statusCode": "200",
#     "headers": {
#         "Content-type": "application/json"
#     },
#     "body": "{\"res\": [{\"2\": \"quarters\"}, {\"2\": \"dimes\"}, {\"1\": \"pennies\"}]}"
# }
#
# Function Logs
# {'amount': '.71'}
#
# Request ID
# d7ec2cad-8da0-4394-957e-41f07bad23ae
# ```

# %% [markdown]
# ## 7.6 Key Terminology

# %% [markdown]
# ### Sagemaker Built-in Algorithms

# %% [markdown]
# #### BlazingText
#
#
# * unsupervised learning algorithm for generating **Word2Vec embeddings.**
# * aws blog post [BlazingText](https://aws.amazon.com/blogs/machine-learning/amazon-sagemaker-blazingtext-parallelizing-word2vec-on-multiple-cpus-or-gpus/)
#
#
#
# ![BlazingText](https://d2908q01vomqb2.cloudfront.net/f1f836cb4ea6efb2a0b1b99f41ad8b103eff4b59/2018/01/18/sagemaker-word2vec-3-1.gif)

# %% [markdown]
# #### DeepAR Forecasting
#
# * supervised learning algorithm for forecasting scalar (that is, one-dimensional) time series using recurrent neural networks (RNN)
# * [DeepAR Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/deepar.html)
#
# ![DeepAR](https://docs.aws.amazon.com/sagemaker/latest/dg/images/deepar-2.png)
